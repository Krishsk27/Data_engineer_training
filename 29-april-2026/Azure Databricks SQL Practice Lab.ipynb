# %%
# %sql
CREATE DATABASE IF NOT EXISTS training_sql_lab;
USE training_sql_lab;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE employees (
emp_id INT,
emp_name STRING,
city STRING,
department STRING,
salary INT,
experience INT
);

# %%
# %sql
INSERT INTO employees VALUES
(101,'Amit Sharma','Hyderabad','Engineering',92000,6),
(102,'Neha Gupta','Bangalore','Marketing',75000,5),
(103,'Rohit Mehta','Mumbai','Finance',88000,7),
(104,'Pooja Reddy','Chennai','Engineering',97000,8),
(105,'Karan Patel','Ahmedabad','HR',69000,4),
(106,'Sneha Iyer','Chennai','Marketing',72000,4),

(107,'Vikram Singh','Delhi','Finance',91000,6),
(108,'Meera Nair','Bangalore','Engineering',85000,5),
(109,'Rahul Verma','Mumbai','Finance',93000,8),
(110,'Ananya Das','Kolkata','Engineering',89000,6),
(111,'Farhan Ali','Hyderabad','HR',67000,3),
(112,'Kavya Reddy','Bangalore','Marketing',76000,5),
(113,'Siddharth Rao','Hyderabad','Engineering',94000,7),
(114,'Divya Menon','Kochi','Finance',99000,9),
(115,'Arjun Nair','Chennai','HR',64000,2),
(116,'Aditya Joshi','Pune','Engineering',96000,8),
(117,'Priya Shah','Ahmedabad','Marketing',74000,4),
(118,'Nikhil Gupta','Delhi','Finance',97000,8),
(119,'Lakshmi Krishnan','Chennai','Engineering',88000,6),
(120,'Manish Yadav','Lucknow','Marketing',77000,5),
(121,'Ayesha Khan','Hyderabad','Finance',91000,7),
(122,'Rakesh Mishra','Delhi','Engineering',86000,6),
(123,'Shalini Kapoor','Mumbai','Marketing',72000,4),
(124,'Deepak Chatterjee','Kolkata','Finance',89000,7),
(125,'Ritu Sharma','Jaipur','HR',65000,3),
(126,'Ankit Jain','Indore','Engineering',94000,7),
(127,'Sanjay Bansal','Delhi','Finance',98000,9),
(128,'Swati Agarwal','Bangalore','Marketing',76000,5),
(129,'Vivek Tiwari','Lucknow','Engineering',87000,6),
(130,'Komal Desai','Ahmedabad','HR',66000,3);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>30</td><td>30</td></tr></tbody></table></div>

# %%
# %sql
CREATE OR REPLACE TABLE projects (
project_id INT,
project_name STRING,
department STRING,
budget INT
);

# %%
# %sql
INSERT INTO projects VALUES
(201,'AI Platform','Engineering',5000000),
(202,'Marketing Automation','Marketing',2000000),
(203,'Financial Risk Model','Finance',3500000),
(204,'HR Analytics','HR',1000000),
(205,'Cloud Migration','Engineering',4500000),
(206,'Digital Campaign','Marketing',1800000),
(207,'Investment Forecast','Finance',3200000),
(208,'Employee Portal','HR',1200000);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

# %%
spark.sql("SELECT * FROM employees").show()
# Out:
# +------+----------------+---------+-----------+------+----------+
# |emp_id|        emp_name|     city| department|salary|experience|
# +------+----------------+---------+-----------+------+----------+
# |   101|     Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   102|      Neha Gupta|Bangalore|  Marketing| 75000|         5|
# |   103|     Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   104|     Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   105|     Karan Patel|Ahmedabad|         HR| 69000|         4|
# |   106|      Sneha Iyer|  Chennai|  Marketing| 72000|         4|
# |   107|    Vikram Singh|    Delhi|    Finance| 91000|         6|
# |   108|      Meera Nair|Bangalore|Engineering| 85000|         5|
# |   109|     Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   110|      Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   111|      Farhan Ali|Hyderabad|         HR| 67000|         3|
# |   112|     Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# |   113|   Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   114|     Divya Menon|    Kochi|    Finance| 99000|         9|
# |   115|      Arjun Nair|  Chennai|         HR| 64000|         2|
# |   116|    Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   117|      Priya Shah|Ahmedabad|  Marketing| 74000|         4|
# |   118|    Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   119|Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|
# |   120|    Manish Yadav|  Lucknow|  Marketing| 77000|         5|
# +------+----------------+---------+-----------+------+----------+
# only showing top 20 rows

# %%
spark.sql("SELECT emp_name, city, salary FROM employees").show()
# Out:
# +----------------+---------+------+
# |        emp_name|     city|salary|
# +----------------+---------+------+
# |     Amit Sharma|Hyderabad| 92000|
# |      Neha Gupta|Bangalore| 75000|
# |     Rohit Mehta|   Mumbai| 88000|
# |     Pooja Reddy|  Chennai| 97000|
# |     Karan Patel|Ahmedabad| 69000|
# |      Sneha Iyer|  Chennai| 72000|
# |    Vikram Singh|    Delhi| 91000|
# |      Meera Nair|Bangalore| 85000|
# |     Rahul Verma|   Mumbai| 93000|
# |      Ananya Das|  Kolkata| 89000|
# |      Farhan Ali|Hyderabad| 67000|
# |     Kavya Reddy|Bangalore| 76000|
# |   Siddharth Rao|Hyderabad| 94000|
# |     Divya Menon|    Kochi| 99000|
# |      Arjun Nair|  Chennai| 64000|
# |    Aditya Joshi|     Pune| 96000|
# |      Priya Shah|Ahmedabad| 74000|
# |    Nikhil Gupta|    Delhi| 97000|
# |Lakshmi Krishnan|  Chennai| 88000|
# |    Manish Yadav|  Lucknow| 77000|
# +----------------+---------+------+
# only showing top 20 rows

# %%
spark.sql("SELECT DISTINCT department FROM employees").show()
# Out:
# +-----------+
# | department|
# +-----------+
# |Engineering|
# |  Marketing|
# |    Finance|
# |         HR|
# +-----------+

# %%
spark.sql("SELECT COUNT(*) FROM employees").show()
# Out:
# +--------+
# |COUNT(*)|
# +--------+
# |      30|
# +--------+

# %%
spark.sql("SELECT * FROM employees WHERE city = 'Hyderabad'").show()
# Out:
# +------+-------------+---------+-----------+------+----------+
# |emp_id|     emp_name|     city| department|salary|experience|
# +------+-------------+---------+-----------+------+----------+
# |   101|  Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   111|   Farhan Ali|Hyderabad|         HR| 67000|         3|
# |   113|Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   121|  Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# +------+-------------+---------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE city = 'Bangalore'").show()
# Out:
# +------+-------------+---------+-----------+------+----------+
# |emp_id|     emp_name|     city| department|salary|experience|
# +------+-------------+---------+-----------+------+----------+
# |   102|   Neha Gupta|Bangalore|  Marketing| 75000|         5|
# |   108|   Meera Nair|Bangalore|Engineering| 85000|         5|
# |   112|  Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# |   128|Swati Agarwal|Bangalore|  Marketing| 76000|         5|
# +------+-------------+---------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE salary > 90000").show()
# Out:
# +------+-------------+---------+-----------+------+----------+
# |emp_id|     emp_name|     city| department|salary|experience|
# +------+-------------+---------+-----------+------+----------+
# |   101|  Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   104|  Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   107| Vikram Singh|    Delhi|    Finance| 91000|         6|
# |   109|  Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   113|Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   114|  Divya Menon|    Kochi|    Finance| 99000|         9|
# |   116| Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   118| Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   121|  Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# |   126|   Ankit Jain|   Indore|Engineering| 94000|         7|
# |   127|Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# +------+-------------+---------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE experience > 6").show()
# Out:
# +------+-----------------+---------+-----------+------+----------+
# |emp_id|         emp_name|     city| department|salary|experience|
# +------+-----------------+---------+-----------+------+----------+
# |   103|      Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   104|      Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   109|      Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   113|    Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   114|      Divya Menon|    Kochi|    Finance| 99000|         9|
# |   116|     Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   118|     Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   121|      Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# |   124|Deepak Chatterjee|  Kolkata|    Finance| 89000|         7|
# |   126|       Ankit Jain|   Indore|Engineering| 94000|         7|
# |   127|    Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# +------+-----------------+---------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE department = 'Engineering'").show()
# Out:
# +------+----------------+---------+-----------+------+----------+
# |emp_id|        emp_name|     city| department|salary|experience|
# +------+----------------+---------+-----------+------+----------+
# |   101|     Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   104|     Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   108|      Meera Nair|Bangalore|Engineering| 85000|         5|
# |   110|      Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   113|   Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   116|    Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   119|Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|
# |   122|   Rakesh Mishra|    Delhi|Engineering| 86000|         6|
# |   126|      Ankit Jain|   Indore|Engineering| 94000|         7|
# |   129|    Vivek Tiwari|  Lucknow|Engineering| 87000|         6|
# +------+----------------+---------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE salary BETWEEN 80000 AND 95000").show()
# Out:
# +------+-----------------+---------+-----------+------+----------+
# |emp_id|         emp_name|     city| department|salary|experience|
# +------+-----------------+---------+-----------+------+----------+
# |   101|      Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   103|      Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   107|     Vikram Singh|    Delhi|    Finance| 91000|         6|
# |   108|       Meera Nair|Bangalore|Engineering| 85000|         5|
# |   109|      Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   110|       Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   113|    Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   119| Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|
# |   121|      Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# |   122|    Rakesh Mishra|    Delhi|Engineering| 86000|         6|
# |   124|Deepak Chatterjee|  Kolkata|    Finance| 89000|         7|
# |   126|       Ankit Jain|   Indore|Engineering| 94000|         7|
# |   129|     Vivek Tiwari|  Lucknow|Engineering| 87000|         6|
# +------+-----------------+---------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees ORDER BY salary ASC").show()
# Out:
# +------+-----------------+---------+-----------+------+----------+
# |emp_id|         emp_name|     city| department|salary|experience|
# +------+-----------------+---------+-----------+------+----------+
# |   115|       Arjun Nair|  Chennai|         HR| 64000|         2|
# |   125|      Ritu Sharma|   Jaipur|         HR| 65000|         3|
# |   130|      Komal Desai|Ahmedabad|         HR| 66000|         3|
# |   111|       Farhan Ali|Hyderabad|         HR| 67000|         3|
# |   105|      Karan Patel|Ahmedabad|         HR| 69000|         4|
# |   106|       Sneha Iyer|  Chennai|  Marketing| 72000|         4|
# |   123|   Shalini Kapoor|   Mumbai|  Marketing| 72000|         4|
# |   117|       Priya Shah|Ahmedabad|  Marketing| 74000|         4|
# |   102|       Neha Gupta|Bangalore|  Marketing| 75000|         5|
# |   112|      Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# |   128|    Swati Agarwal|Bangalore|  Marketing| 76000|         5|
# |   120|     Manish Yadav|  Lucknow|  Marketing| 77000|         5|
# |   108|       Meera Nair|Bangalore|Engineering| 85000|         5|
# |   122|    Rakesh Mishra|    Delhi|Engineering| 86000|         6|
# |   129|     Vivek Tiwari|  Lucknow|Engineering| 87000|         6|
# |   103|      Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   119| Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|
# |   110|       Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   124|Deepak Chatterjee|  Kolkata|    Finance| 89000|         7|
# |   107|     Vikram Singh|    Delhi|    Finance| 91000|         6|
# +------+-----------------+---------+-----------+------+----------+
# only showing top 20 rows

# %%
spark.sql("SELECT * FROM employees ORDER BY salary DESC").show()
# Out:
# +------+-----------------+---------+-----------+------+----------+
# |emp_id|         emp_name|     city| department|salary|experience|
# +------+-----------------+---------+-----------+------+----------+
# |   114|      Divya Menon|    Kochi|    Finance| 99000|         9|
# |   127|    Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# |   118|     Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   104|      Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   116|     Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   113|    Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   126|       Ankit Jain|   Indore|Engineering| 94000|         7|
# |   109|      Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   101|      Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   121|      Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# |   107|     Vikram Singh|    Delhi|    Finance| 91000|         6|
# |   124|Deepak Chatterjee|  Kolkata|    Finance| 89000|         7|
# |   110|       Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   103|      Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   119| Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|
# |   129|     Vivek Tiwari|  Lucknow|Engineering| 87000|         6|
# |   122|    Rakesh Mishra|    Delhi|Engineering| 86000|         6|
# |   108|       Meera Nair|Bangalore|Engineering| 85000|         5|
# |   120|     Manish Yadav|  Lucknow|  Marketing| 77000|         5|
# |   112|      Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# +------+-----------------+---------+-----------+------+----------+
# only showing top 20 rows

# %%
spark.sql("SELECT * FROM employees ORDER BY salary DESC LIMIT 5").show()
# Out:
# +------+-------------+-------+-----------+------+----------+
# |emp_id|     emp_name|   city| department|salary|experience|
# +------+-------------+-------+-----------+------+----------+
# |   114|  Divya Menon|  Kochi|    Finance| 99000|         9|
# |   127|Sanjay Bansal|  Delhi|    Finance| 98000|         9|
# |   104|  Pooja Reddy|Chennai|Engineering| 97000|         8|
# |   118| Nikhil Gupta|  Delhi|    Finance| 97000|         8|
# |   116| Aditya Joshi|   Pune|Engineering| 96000|         8|
# +------+-------------+-------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees ORDER BY salary ASC LIMIT 5").show()
# Out:
# +------+-----------+---------+----------+------+----------+
# |emp_id|   emp_name|     city|department|salary|experience|
# +------+-----------+---------+----------+------+----------+
# |   115| Arjun Nair|  Chennai|        HR| 64000|         2|
# |   125|Ritu Sharma|   Jaipur|        HR| 65000|         3|
# |   130|Komal Desai|Ahmedabad|        HR| 66000|         3|
# |   111| Farhan Ali|Hyderabad|        HR| 67000|         3|
# |   105|Karan Patel|Ahmedabad|        HR| 69000|         4|
# +------+-----------+---------+----------+------+----------+

# %%
spark.sql("SELECT * FROM employees ORDER BY experience DESC").show()
# Out:
# +------+-----------------+---------+-----------+------+----------+
# |emp_id|         emp_name|     city| department|salary|experience|
# +------+-----------------+---------+-----------+------+----------+
# |   114|      Divya Menon|    Kochi|    Finance| 99000|         9|
# |   127|    Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# |   116|     Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   118|     Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   109|      Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   104|      Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   121|      Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# |   126|       Ankit Jain|   Indore|Engineering| 94000|         7|
# |   113|    Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   124|Deepak Chatterjee|  Kolkata|    Finance| 89000|         7|
# |   103|      Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   107|     Vikram Singh|    Delhi|    Finance| 91000|         6|
# |   110|       Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   129|     Vivek Tiwari|  Lucknow|Engineering| 87000|         6|
# |   101|      Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   119| Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|
# |   122|    Rakesh Mishra|    Delhi|Engineering| 86000|         6|
# |   112|      Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# |   120|     Manish Yadav|  Lucknow|  Marketing| 77000|         5|
# |   108|       Meera Nair|Bangalore|Engineering| 85000|         5|
# +------+-----------------+---------+-----------+------+----------+
# only showing top 20 rows

# %%
spark.sql("SELECT AVG(salary) FROM employees").show()
spark.sql("SELECT MAX(salary) FROM employees").show()
spark.sql("SELECT MIN(salary) FROM employees").show()
# Out:
# +-----------------+
# |      AVG(salary)|
# +-----------------+
# |83566.66666666667|
# +-----------------+
#
# +-----------+
# |MAX(salary)|
# +-----------+
# |      99000|
# +-----------+
#
# +-----------+
# |MIN(salary)|
# +-----------+
# |      64000|
# +-----------+

# %%
spark.sql("SELECT department, COUNT(*) FROM employees GROUP BY department").show()
spark.sql("SELECT department, AVG(salary) FROM employees GROUP BY department").show()
# Out:
# +-----------+--------+
# | department|COUNT(*)|
# +-----------+--------+
# |Engineering|      10|
# |  Marketing|       7|
# |    Finance|       8|
# |         HR|       5|
# +-----------+--------+
#
# +-----------+-----------------+
# | department|      AVG(salary)|
# +-----------+-----------------+
# |Engineering|          90800.0|
# |  Marketing|74571.42857142857|
# |    Finance|          93250.0|
# |         HR|          66200.0|
# +-----------+-----------------+

# %%
spark.sql("SELECT department, SUM(salary) FROM employees GROUP BY department").show()
# Out:
# +-----------+-----------+
# | department|SUM(salary)|
# +-----------+-----------+
# |Engineering|     908000|
# |  Marketing|     522000|
# |    Finance|     746000|
# |         HR|     331000|
# +-----------+-----------+

# %%
spark.sql("SELECT department, AVG(experience) FROM employees GROUP BY department").show()
# Out:
# +-----------+-----------------+
# | department|  AVG(experience)|
# +-----------+-----------------+
# |Engineering|              6.5|
# |  Marketing|4.571428571428571|
# |    Finance|            7.625|
# |         HR|              3.0|
# +-----------+-----------------+

# %%
spark.sql("SELECT city, COUNT(*) FROM employees GROUP BY city").show()
# Out:
# +---------+--------+
# |     city|COUNT(*)|
# +---------+--------+
# |Hyderabad|       4|
# |Bangalore|       4|
# |   Mumbai|       3|
# |  Chennai|       4|
# |Ahmedabad|       3|
# |    Delhi|       4|
# |  Kolkata|       2|
# |    Kochi|       1|
# |     Pune|       1|
# |  Lucknow|       2|
# |   Jaipur|       1|
# |   Indore|       1|
# +---------+--------+

# %%
spark.sql("SELECT city, MAX(salary) FROM employees GROUP BY city").show()
# Out:
# +---------+-----------+
# |     city|MAX(salary)|
# +---------+-----------+
# |Hyderabad|      94000|
# |Bangalore|      85000|
# |   Mumbai|      93000|
# |  Chennai|      97000|
# |Ahmedabad|      74000|
# |    Delhi|      98000|
# |  Kolkata|      89000|
# |    Kochi|      99000|
# |     Pune|      96000|
# |  Lucknow|      87000|
# |   Jaipur|      65000|
# |   Indore|      94000|
# +---------+-----------+

# %%
spark.sql("SELECT department, MIN(salary) FROM employees GROUP BY department").show()
# Out:
# +-----------+-----------+
# | department|MIN(salary)|
# +-----------+-----------+
# |Engineering|      85000|
# |  Marketing|      72000|
# |    Finance|      88000|
# |         HR|      64000|
# +-----------+-----------+

# %%
spark.sql("""
SELECT * FROM employees
WHERE salary > (SELECT AVG(salary) FROM employees)
""").show()
# Out:
# +------+-----------------+---------+-----------+------+----------+
# |emp_id|         emp_name|     city| department|salary|experience|
# +------+-----------------+---------+-----------+------+----------+
# |   101|      Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   103|      Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   104|      Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   107|     Vikram Singh|    Delhi|    Finance| 91000|         6|
# |   108|       Meera Nair|Bangalore|Engineering| 85000|         5|
# |   109|      Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   110|       Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   113|    Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   114|      Divya Menon|    Kochi|    Finance| 99000|         9|
# |   116|     Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   118|     Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   119| Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|
# |   121|      Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# |   122|    Rakesh Mishra|    Delhi|Engineering| 86000|         6|
# |   124|Deepak Chatterjee|  Kolkata|    Finance| 89000|         7|
# |   126|       Ankit Jain|   Indore|Engineering| 94000|         7|
# |   127|    Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# |   129|     Vivek Tiwari|  Lucknow|Engineering| 87000|         6|
# +------+-----------------+---------+-----------+------+----------+

# %%
spark.sql("""
SELECT * FROM employees e
WHERE experience > (
    SELECT AVG(experience)
    FROM employees
    WHERE department = e.department
)
""").show()
# Out:
# +------+-------------+---------+-----------+------+----------+
# |emp_id|     emp_name|     city| department|salary|experience|
# +------+-------------+---------+-----------+------+----------+
# |   102|   Neha Gupta|Bangalore|  Marketing| 75000|         5|
# |   104|  Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   105|  Karan Patel|Ahmedabad|         HR| 69000|         4|
# |   109|  Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   112|  Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# |   113|Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   114|  Divya Menon|    Kochi|    Finance| 99000|         9|
# |   116| Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   118| Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   120| Manish Yadav|  Lucknow|  Marketing| 77000|         5|
# |   126|   Ankit Jain|   Indore|Engineering| 94000|         7|
# |   127|Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# |   128|Swati Agarwal|Bangalore|  Marketing| 76000|         5|
# +------+-------------+---------+-----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE salary < 70000").show()
# Out:
# +------+-----------+---------+----------+------+----------+
# |emp_id|   emp_name|     city|department|salary|experience|
# +------+-----------+---------+----------+------+----------+
# |   105|Karan Patel|Ahmedabad|        HR| 69000|         4|
# |   111| Farhan Ali|Hyderabad|        HR| 67000|         3|
# |   115| Arjun Nair|  Chennai|        HR| 64000|         2|
# |   125|Ritu Sharma|   Jaipur|        HR| 65000|         3|
# |   130|Komal Desai|Ahmedabad|        HR| 66000|         3|
# +------+-----------+---------+----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE department = 'HR'").show()
# Out:
# +------+-----------+---------+----------+------+----------+
# |emp_id|   emp_name|     city|department|salary|experience|
# +------+-----------+---------+----------+------+----------+
# |   105|Karan Patel|Ahmedabad|        HR| 69000|         4|
# |   111| Farhan Ali|Hyderabad|        HR| 67000|         3|
# |   115| Arjun Nair|  Chennai|        HR| 64000|         2|
# |   125|Ritu Sharma|   Jaipur|        HR| 65000|         3|
# |   130|Komal Desai|Ahmedabad|        HR| 66000|         3|
# +------+-----------+---------+----------+------+----------+

# %%
spark.sql("SELECT * FROM employees WHERE department = 'Finance' AND salary > 90000").show()
# Out:
# +------+-------------+---------+----------+------+----------+
# |emp_id|     emp_name|     city|department|salary|experience|
# +------+-------------+---------+----------+------+----------+
# |   107| Vikram Singh|    Delhi|   Finance| 91000|         6|
# |   109|  Rahul Verma|   Mumbai|   Finance| 93000|         8|
# |   114|  Divya Menon|    Kochi|   Finance| 99000|         9|
# |   118| Nikhil Gupta|    Delhi|   Finance| 97000|         8|
# |   121|  Ayesha Khan|Hyderabad|   Finance| 91000|         7|
# |   127|Sanjay Bansal|    Delhi|   Finance| 98000|         9|
# +------+-------------+---------+----------+------+----------+

# %%
spark.sql("""
SELECT e.*, p.budget
FROM employees e
JOIN projects p
ON e.department = p.department
""").show()
# Out:
# +------+----------------+---------+-----------+------+----------+-------+
# |emp_id|        emp_name|     city| department|salary|experience| budget|
# +------+----------------+---------+-----------+------+----------+-------+
# |   101|     Amit Sharma|Hyderabad|Engineering| 92000|         6|4500000|
# |   102|      Neha Gupta|Bangalore|  Marketing| 75000|         5|1800000|
# |   103|     Rohit Mehta|   Mumbai|    Finance| 88000|         7|3200000|
# |   104|     Pooja Reddy|  Chennai|Engineering| 97000|         8|4500000|
# |   105|     Karan Patel|Ahmedabad|         HR| 69000|         4|1200000|
# |   106|      Sneha Iyer|  Chennai|  Marketing| 72000|         4|1800000|
# |   107|    Vikram Singh|    Delhi|    Finance| 91000|         6|3200000|
# |   108|      Meera Nair|Bangalore|Engineering| 85000|         5|4500000|
# |   109|     Rahul Verma|   Mumbai|    Finance| 93000|         8|3200000|
# |   110|      Ananya Das|  Kolkata|Engineering| 89000|         6|4500000|
# |   111|      Farhan Ali|Hyderabad|         HR| 67000|         3|1200000|
# |   112|     Kavya Reddy|Bangalore|  Marketing| 76000|         5|1800000|
# |   113|   Siddharth Rao|Hyderabad|Engineering| 94000|         7|4500000|
# |   114|     Divya Menon|    Kochi|    Finance| 99000|         9|3200000|
# |   115|      Arjun Nair|  Chennai|         HR| 64000|         2|1200000|
# |   116|    Aditya Joshi|     Pune|Engineering| 96000|         8|4500000|
# |   117|      Priya Shah|Ahmedabad|  Marketing| 74000|         4|1800000|
# |   118|    Nikhil Gupta|    Delhi|    Finance| 97000|         8|3200000|
# |   119|Lakshmi Krishnan|  Chennai|Engineering| 88000|         6|4500000|
# |   120|    Manish Yadav|  Lucknow|  Marketing| 77000|         5|1800000|
# +------+----------------+---------+-----------+------+----------+-------+
# only showing top 20 rows

# %%
spark.sql("""
SELECT e.emp_name, e.department, p.project_name
FROM employees e
JOIN projects p
ON e.department = p.department
""").show()
# Out:
# +----------------+-----------+-------------------+
# |        emp_name| department|       project_name|
# +----------------+-----------+-------------------+
# |     Amit Sharma|Engineering|    Cloud Migration|
# |      Neha Gupta|  Marketing|   Digital Campaign|
# |     Rohit Mehta|    Finance|Investment Forecast|
# |     Pooja Reddy|Engineering|    Cloud Migration|
# |     Karan Patel|         HR|    Employee Portal|
# |      Sneha Iyer|  Marketing|   Digital Campaign|
# |    Vikram Singh|    Finance|Investment Forecast|
# |      Meera Nair|Engineering|    Cloud Migration|
# |     Rahul Verma|    Finance|Investment Forecast|
# |      Ananya Das|Engineering|    Cloud Migration|
# |      Farhan Ali|         HR|    Employee Portal|
# |     Kavya Reddy|  Marketing|   Digital Campaign|
# |   Siddharth Rao|Engineering|    Cloud Migration|
# |     Divya Menon|    Finance|Investment Forecast|
# |      Arjun Nair|         HR|    Employee Portal|
# |    Aditya Joshi|Engineering|    Cloud Migration|
# |      Priya Shah|  Marketing|   Digital Campaign|
# |    Nikhil Gupta|    Finance|Investment Forecast|
# |Lakshmi Krishnan|Engineering|    Cloud Migration|
# |    Manish Yadav|  Marketing|   Digital Campaign|
# +----------------+-----------+-------------------+
# only showing top 20 rows

# %%
spark.sql("""
SELECT department, SUM(budget)
FROM projects
GROUP BY department
""").show()
# Out:
# +-----------+-----------+
# | department|SUM(budget)|
# +-----------+-----------+
# |Engineering|    9500000|
# |  Marketing|    3800000|
# |    Finance|    6700000|
# |         HR|    2200000|
# +-----------+-----------+

# %%
spark.sql("""
SELECT DISTINCT e.*
FROM employees e
JOIN projects p
ON e.department = p.department
""").show()
# Out:
# +------+-----------------+---------+-----------+------+----------+
# |emp_id|         emp_name|     city| department|salary|experience|
# +------+-----------------+---------+-----------+------+----------+
# |   108|       Meera Nair|Bangalore|Engineering| 85000|         5|
# |   110|       Ananya Das|  Kolkata|Engineering| 89000|         6|
# |   117|       Priya Shah|Ahmedabad|  Marketing| 74000|         4|
# |   128|    Swati Agarwal|Bangalore|  Marketing| 76000|         5|
# |   121|      Ayesha Khan|Hyderabad|    Finance| 91000|         7|
# |   126|       Ankit Jain|   Indore|Engineering| 94000|         7|
# |   109|      Rahul Verma|   Mumbai|    Finance| 93000|         8|
# |   127|    Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# |   103|      Rohit Mehta|   Mumbai|    Finance| 88000|         7|
# |   105|      Karan Patel|Ahmedabad|         HR| 69000|         4|
# |   107|     Vikram Singh|    Delhi|    Finance| 91000|         6|
# |   115|       Arjun Nair|  Chennai|         HR| 64000|         2|
# |   122|    Rakesh Mishra|    Delhi|Engineering| 86000|         6|
# |   130|      Komal Desai|Ahmedabad|         HR| 66000|         3|
# |   124|Deepak Chatterjee|  Kolkata|    Finance| 89000|         7|
# |   129|     Vivek Tiwari|  Lucknow|Engineering| 87000|         6|
# |   111|       Farhan Ali|Hyderabad|         HR| 67000|         3|
# |   116|     Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   118|     Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   112|      Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# +------+-----------------+---------+-----------+------+----------+
# only showing top 20 rows

# %%
spark.sql("""
SELECT p.project_name, COUNT(e.emp_id)
FROM employees e
JOIN projects p
ON e.department = p.department
GROUP BY p.project_name
""").show()
# Out:
# +--------------------+---------------+
# |        project_name|COUNT(e.emp_id)|
# +--------------------+---------------+
# |    Digital Campaign|              7|
# |     Employee Portal|              5|
# |Marketing Automation|              7|
# |     Cloud Migration|             10|
# |        HR Analytics|              5|
# |         AI Platform|             10|
# |Financial Risk Model|              8|
# | Investment Forecast|              8|
# +--------------------+---------------+

# %%
spark.sql("""
SELECT *
FROM employees
WHERE department = 'Engineering'
ORDER BY salary DESC
LIMIT 3
""").show()
# Out:
# +------+-------------+---------+-----------+------+----------+
# |emp_id|     emp_name|     city| department|salary|experience|
# +------+-------------+---------+-----------+------+----------+
# |   104|  Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   116| Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   113|Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# +------+-------------+---------+-----------+------+----------+

# %%
spark.sql("""
SELECT department
FROM employees
GROUP BY department
ORDER BY AVG(salary) DESC
LIMIT 1
""").show()
# Out:
# +----------+
# |department|
# +----------+
# |   Finance|
# +----------+

# %%
spark.sql("""
SELECT city
FROM employees
GROUP BY city
ORDER BY COUNT(*) DESC
LIMIT 1
""").show()
# Out:
# +---------+
# |     city|
# +---------+
# |Hyderabad|
# +---------+

# %%
spark.sql("""
SELECT *
FROM employees e
WHERE salary > (
    SELECT AVG(salary)
    FROM employees
    WHERE department = e.department
)
""").show()
# Out:
# +------+-------------+---------+-----------+------+----------+
# |emp_id|     emp_name|     city| department|salary|experience|
# +------+-------------+---------+-----------+------+----------+
# |   101|  Amit Sharma|Hyderabad|Engineering| 92000|         6|
# |   102|   Neha Gupta|Bangalore|  Marketing| 75000|         5|
# |   104|  Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   105|  Karan Patel|Ahmedabad|         HR| 69000|         4|
# |   111|   Farhan Ali|Hyderabad|         HR| 67000|         3|
# |   112|  Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# |   113|Siddharth Rao|Hyderabad|Engineering| 94000|         7|
# |   114|  Divya Menon|    Kochi|    Finance| 99000|         9|
# |   116| Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   118| Nikhil Gupta|    Delhi|    Finance| 97000|         8|
# |   120| Manish Yadav|  Lucknow|  Marketing| 77000|         5|
# |   126|   Ankit Jain|   Indore|Engineering| 94000|         7|
# |   127|Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# |   128|Swati Agarwal|Bangalore|  Marketing| 76000|         5|
# +------+-------------+---------+-----------+------+----------+

# %%
spark.sql("""
SELECT *
FROM employees e
WHERE experience = (
    SELECT MAX(experience)
    FROM employees
    WHERE department = e.department
)
""").show()
# Out:
# +------+-------------+---------+-----------+------+----------+
# |emp_id|     emp_name|     city| department|salary|experience|
# +------+-------------+---------+-----------+------+----------+
# |   102|   Neha Gupta|Bangalore|  Marketing| 75000|         5|
# |   104|  Pooja Reddy|  Chennai|Engineering| 97000|         8|
# |   105|  Karan Patel|Ahmedabad|         HR| 69000|         4|
# |   112|  Kavya Reddy|Bangalore|  Marketing| 76000|         5|
# |   114|  Divya Menon|    Kochi|    Finance| 99000|         9|
# |   116| Aditya Joshi|     Pune|Engineering| 96000|         8|
# |   120| Manish Yadav|  Lucknow|  Marketing| 77000|         5|
# |   127|Sanjay Bansal|    Delhi|    Finance| 98000|         9|
# |   128|Swati Agarwal|Bangalore|  Marketing| 76000|         5|
# +------+-------------+---------+-----------+------+----------+

# %%
spark.sql("""
CREATE OR REPLACE TABLE employee_salary_analysis AS
SELECT
    emp_name,
    city,
    department,
    salary,
    experience,
    CASE
        WHEN salary >= 95000 THEN 'High'
        WHEN salary >= 80000 THEN 'Medium'
        ELSE 'Low'
    END AS salary_category,
    AVG(salary) OVER (PARTITION BY department) AS department_avg_salary
FROM employees
""")
# Out:
# DataFrame[num_affected_rows: bigint, num_inserted_rows: bigint]
