# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import col, rank, dense_rank
data = [
(1, "Ravi Kumar", "Engineering", "Hyderabad", 92000),
(2, "Sneha Reddy", "Engineering", "Bengaluru", 97000),
(3, "Amit Shah", "Finance", "Mumbai", 88000),
(4, "Pooja Nair", "HR", "Chennai", 69000),
(5, "Nikhil Verma", "Engineering", "Delhi", 85000),
(6, "Meera Iyer", "Finance", "Hyderabad", 91000),
(7, "Karan Malhotra", "Marketing", "Mumbai", 76000),
(8, "Anjali Rao", "HR", "Bengaluru", 72000),
(9, "Vivek Joshi", "Finance", "Delhi", 94000),
(10, "Fatima Khan", "Marketing", "Chennai", 81000),
(11, "Aditya Menon", "Engineering", "Mumbai", 99000),
(12, "Lakshmi Das", "Finance", "Bengaluru", 87000)
]
columns = ["emp_id", "emp_name", "department", "city", "salary"]
df = spark.createDataFrame(data, columns)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>city</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Ravi Kumar</td><td>Engineering</td><td>Hyderabad</td><td>92000</td></tr><tr><td>2</td><td>Sneha Reddy</td><td>Engineering</td><td>Bengaluru</td><td>97000</td></tr><tr><td>3</td><td>Amit Shah</td><td>Finance</td><td>Mumbai</td><td>88000</td></tr><tr><td>4</td><td>Pooja Nair</td><td>HR</td><td>Chennai</td><td>69000</td></tr><tr><td>5</td><td>Nikhil Verma</td><td>Engineering</td><td>Delhi</td><td>85000</td></tr><tr><td>6</td><td>Meera Iyer</td><td>Finance</td><td>Hyderabad</td><td>91000</td></tr><tr><td>7</td><td>Karan Malhotra</td><td>Marketing</td><td>Mumbai</td><td>76000</td></tr><tr><td>8</td><td>Anjali Rao</td><td>HR</td><td>Bengaluru</td><td>72000</td></tr><tr><td>9</td><td>Vivek Joshi</td><td>Finance</td><td>Delhi</td><td>94000</td></tr><tr><td>10</td><td>Fatima Khan</td><td>Marketing</td><td>Chennai</td><td>81000</td></tr><tr><td>11</td><td>Aditya Menon</td><td>Engineering</td><td>Mumbai</td><td>99000</td></tr><tr><td>12</td><td>Lakshmi Das</td><td>Finance</td><td>Bengaluru</td><td>87000</td></tr></tbody></table></div>

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import col, rank, dense_rank, desc, when, avg

# %%
window_spec = Window.partitionBy("department").orderBy(desc("salary"))

# %%
df_ranked = df.withColumn("rank", rank().over(window_spec)) \
              .withColumn("dense_rank", dense_rank().over(window_spec))

df_ranked.show()
# Out:
# +------+--------------+-----------+---------+------+----+----------+
# |emp_id|      emp_name| department|     city|salary|rank|dense_rank|
# +------+--------------+-----------+---------+------+----+----------+
# |    11|  Aditya Menon|Engineering|   Mumbai| 99000|   1|         1|
# |     2|   Sneha Reddy|Engineering|Bengaluru| 97000|   2|         2|
# |     1|    Ravi Kumar|Engineering|Hyderabad| 92000|   3|         3|
# |     5|  Nikhil Verma|Engineering|    Delhi| 85000|   4|         4|
# |     9|   Vivek Joshi|    Finance|    Delhi| 94000|   1|         1|
# |     6|    Meera Iyer|    Finance|Hyderabad| 91000|   2|         2|
# |     3|     Amit Shah|    Finance|   Mumbai| 88000|   3|         3|
# |    12|   Lakshmi Das|    Finance|Bengaluru| 87000|   4|         4|
# |     8|    Anjali Rao|         HR|Bengaluru| 72000|   1|         1|
# |     4|    Pooja Nair|         HR|  Chennai| 69000|   2|         2|
# |    10|   Fatima Khan|  Marketing|  Chennai| 81000|   1|         1|
# |     7|Karan Malhotra|  Marketing|   Mumbai| 76000|   2|         2|
# +------+--------------+-----------+---------+------+----+----------+

# %%
df_salary_level = df.withColumn("salary_level", 
    when(col("salary") >= 95000, "Very High")
    .when(col("salary") >= 85000, "High")
    .otherwise("Standard")
)

display(df_salary_level)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>city</th><th>salary</th><th>salary_level</th></tr></thead><tbody><tr><td>1</td><td>Ravi Kumar</td><td>Engineering</td><td>Hyderabad</td><td>92000</td><td>High</td></tr><tr><td>2</td><td>Sneha Reddy</td><td>Engineering</td><td>Bengaluru</td><td>97000</td><td>Very High</td></tr><tr><td>3</td><td>Amit Shah</td><td>Finance</td><td>Mumbai</td><td>88000</td><td>High</td></tr><tr><td>4</td><td>Pooja Nair</td><td>HR</td><td>Chennai</td><td>69000</td><td>Standard</td></tr><tr><td>5</td><td>Nikhil Verma</td><td>Engineering</td><td>Delhi</td><td>85000</td><td>High</td></tr><tr><td>6</td><td>Meera Iyer</td><td>Finance</td><td>Hyderabad</td><td>91000</td><td>High</td></tr><tr><td>7</td><td>Karan Malhotra</td><td>Marketing</td><td>Mumbai</td><td>76000</td><td>Standard</td></tr><tr><td>8</td><td>Anjali Rao</td><td>HR</td><td>Bengaluru</td><td>72000</td><td>Standard</td></tr><tr><td>9</td><td>Vivek Joshi</td><td>Finance</td><td>Delhi</td><td>94000</td><td>High</td></tr><tr><td>10</td><td>Fatima Khan</td><td>Marketing</td><td>Chennai</td><td>81000</td><td>Standard</td></tr><tr><td>11</td><td>Aditya Menon</td><td>Engineering</td><td>Mumbai</td><td>99000</td><td>Very High</td></tr><tr><td>12</td><td>Lakshmi Das</td><td>Finance</td><td>Bengaluru</td><td>87000</td><td>High</td></tr></tbody></table></div>

# %%
top_2_df = df_ranked.filter(col("rank") <= 2)
top_2_df.show()
# Out:
# +------+--------------+-----------+---------+------+----+----------+
# |emp_id|      emp_name| department|     city|salary|rank|dense_rank|
# +------+--------------+-----------+---------+------+----+----------+
# |    11|  Aditya Menon|Engineering|   Mumbai| 99000|   1|         1|
# |     2|   Sneha Reddy|Engineering|Bengaluru| 97000|   2|         2|
# |     9|   Vivek Joshi|    Finance|    Delhi| 94000|   1|         1|
# |     6|    Meera Iyer|    Finance|Hyderabad| 91000|   2|         2|
# |     8|    Anjali Rao|         HR|Bengaluru| 72000|   1|         1|
# |     4|    Pooja Nair|         HR|  Chennai| 69000|   2|         2|
# |    10|   Fatima Khan|  Marketing|  Chennai| 81000|   1|         1|
# |     7|Karan Malhotra|  Marketing|   Mumbai| 76000|   2|         2|
# +------+--------------+-----------+---------+------+----+----------+

# %%
df_avg_salary = df.groupBy("department").agg(
    avg("salary").alias("avg_salary")
)

df_avg_salary.show()
# Out:
# +-----------+----------+
# | department|avg_salary|
# +-----------+----------+
# |Engineering|   93250.0|
# |    Finance|   90000.0|
# |         HR|   70500.0|
# |  Marketing|   78500.0|
# +-----------+----------+
